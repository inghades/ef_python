# %%
# %matplotlib notebook  

from ef_jupyter_visualize import *

efconf = EfConf()

time_grid = TimeGrid(
    total_time = 5.0e-10,
    time_save_step = 5.0e-11,
    time_step_size = 5.0e-11,
)

spat_mesh = SpatialMesh(
    grid_x_size = 0.5,
    grid_x_step = 0.05,
    grid_y_size = 0.5,
    grid_y_step = 0.05,
    grid_z_size = 0.45,
    grid_z_step = 0.05
)

efconf.time_grid = time_grid
efconf.spatial_mesh = spat_mesh
efconf.visualize()
# Out:
# <img src="data:image/png;base64,...">

# %%
cyl_souce = ParticleSourceCylinder(
    name = 'cathode_emitter',
    initial_number_of_particles = 300,
    particles_to_generate_each_step = 300,
    cylinder_axis_start_x=0.25,
    cylinder_axis_start_y=0.25,
    cylinder_axis_start_z=0.2,
    cylinder_axis_end_x=0.25,
    cylinder_axis_end_y=0.25,
    cylinder_axis_end_z=0.3,
    cylinder_in_radius=0.05,
    cylinder_out_radius=0.1,
    mean_momentum_x = 0,
    mean_momentum_y = 0,
    mean_momentum_z = 9.5e-17,
    temperature = 0.0,
    charge = -1.5e-07,
    mass = 2.8e-25 )
efconf.add_source( cyl_souce )
efconf.visualize()
# Out:
# <img src="data:image/png;base64,...">

# %%
efconf.run()
# Out:
# command: python3 ../../main.py /tmp/tmps6vgbog9.ini
# b'1210 1210'
# b'Writing step 0 to file out_0000000.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 300'
# b'Time step from 0 to 1 of 10'
# b'Writing step 1 to file out_0000001.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 600'
# b'Time step from 1 to 2 of 10'
# b'Writing step 2 to file out_0000002.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 900'
# b'Time step from 2 to 3 of 10'
# b'Writing step 3 to file out_0000003.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 1200'
# b'Time step from 3 to 4 of 10'
# b'Writing step 4 to file out_0000004.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 1500'
# b'Time step from 4 to 5 of 10'
# b'Writing step 5 to file out_0000005.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 1800'
# b'Time step from 5 to 6 of 10'
# b'Writing step 6 to file out_0000006.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 2100'
# b'Time step from 6 to 7 of 10'
# b'Writing step 7 to file out_0000007.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 2400'
# b'Time step from 7 to 8 of 10'
# b'Writing step 8 to file out_0000008.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 2700'
# b'Time step from 8 to 9 of 10'
# b'Writing step 9 to file out_0000009.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 2992'
# b'Time step from 9 to 10 of 10'
# b'Writing step 10 to file out_0000010.h5'
# b'1210 1210'
# b'Source name = cathode_emitter, number of particles = 3229'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-4ab6aba01886> in <module>()
# ----> 1 efconf.run()
#
# ~/ef_python_dev/examples/test_cyl_part_source/ef_jupyter_visualize.py in run(self, ef_command, workdir, save_config_as)
#     124             command = ef_command + " " + tmpfilename
#     125         print( "command:", command )
# --> 126         self.run_command( command )
#     127         #stdout = subprocess.Popen( command, shell = True,
#     128         #                           stdout = subprocess.PIPE ).stdout.read()
#
# ~/ef_python_dev/examples/test_cyl_part_source/ef_jupyter_visualize.py in run_command(self, command)
#     151         process = subprocess.Popen(shlex.split(command), stdout=subprocess.PIPE)
#     152         while True:
# --> 153             output = process.stdout.readline()
#     154             if output == '' and process.poll() is not None:
#     155                 break
#
# KeyboardInterrupt:

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import h5py
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.gca(projection='3d')

filename = 'out_0000010.h5'
h5 = h5py.File( filename , mode="r") # read h5 file


ax.plot(h5["/Particle_sources/cathode_emitter/position_x"][:],
         h5["/Particle_sources/cathode_emitter/position_y"][:],
h5["/Particle_sources/cathode_emitter/position_z"][:],'.')
# Out:
# <img src="data:image/png;base64,...">
